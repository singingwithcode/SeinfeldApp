# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('scripts.csv')
df
# Out:
#        Unnamed: 0   Character  \
# 0               0       JERRY
# 1               1       JERRY
# 2               2      GEORGE
# 3               3       JERRY
# 4               4      GEORGE
# ...           ...         ...
# 54611       54611       JERRY
# 54612       54612  PRISONER 3
# 54613       54613       JERRY
# 54614       54614       GUARD
# 54615       54615       JERRY
#
#                                                 Dialogue  EpisodeNo    SEID  \
# 0      Do you know what this is all about? Do you kno...        1.0  S01E01
# 1      (pointing at Georges shirt) See, to me, that b...        1.0  S01E01
# 2                                       Are you through?        1.0  S01E01
# 3                 You do of course try on, when you buy?        1.0  S01E01
# 4      Yes, it was purple, I liked it, I dont actuall...        1.0  S01E01
# ...                                                  ...        ...     ...
# ...

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

df['Dialogue'] = df['Dialogue'].astype(str)

# Remove stop words from 'Dialogue' column in df
df['Dialogue'] = df['Dialogue'].apply(lambda x: ' '.join([word for word in x.split() if word.lower() not in stop_words]))
# Out:
# [nltk_data] Downloading package stopwords to /Users/joshpressler-
# [nltk_data]     shell/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df.sample(10)
# Out:
#        Unnamed: 0 Character  \
# 24506       24506   ESTELLE
# 27581       27581    GEORGE
# 3879         3879    GEORGE
# 48075       48075     PATTY
# 7800         7800     JERRY
# 5181         5181     JERRY
# 25865       25865    KRAMER
# 53565       53565    KRUGER
# 41540       41540      ANNA
# 14718       14718     NURSE
#
#                                                 Dialogue  EpisodeNo    SEID  \
# 24506  (with arms wonder) ever them? (George puts arm...       18.0  S05E18
# 27581   Hunh, pph (raises hands slightly, amazement) it?        7.0  S06E07
# 3879                          (Unconvincingly coy) what?       10.0  S02E10
# 48075                             Sarcastically) Uh huh.        3.0  S09E03
# 7800                                           hard say.       12.0  S03E12
# 5181                           We'll stay hotel tonight.        3.0  S03E03
# 25865            Tape breasts together. (Jerry shocked.)        1.0  S06E01
# ...

# %%
valid_names = ['JERRY', 'GEORGE', 'ELAINE', 'KRAMER', 'NEWMAN', 'MORTY', 'HELEN', 'FRANK']

# keep only rows where 'Character' is in valid_names
df = df[df['Character'].isin(valid_names)]

# %%
df.sample(30)
# Out:
#        Unnamed: 0 Character  \
# 53705       53705    KRAMER
# 31330       31330    ELAINE
# 29816       29816    GEORGE
# 2099         2099    GEORGE
# 27530       27530    ELAINE
# 22718       22718     JERRY
# 52013       52013    ELAINE
# 5182         5182    ELAINE
# 21410       21410     JERRY
# 24120       24120    GEORGE
# 43897       43897    KRAMER
# 11648       11648     JERRY
# 9787         9787     JERRY
# 12547       12547     JERRY
# 15782       15782    GEORGE
# 11744       11744    KRAMER
# 33805       33805     JERRY
# 16749       16749    ELAINE
# 4086         4086    ELAINE
# 22929       22929     JERRY
# 51999       51999    GEORGE
# 30547       30547    KRAMER
# 2897         2897    KRAMER
# 53200       53200    GEORGE
# 47230       47230    GEORGE
# 25495       25495    ELAINE
# 25703       25703    ELAINE
# 30866       30866     JERRY
# 40548       40548     JERRY
# 53970       53970     JERRY
#
# ...

# %%
df.to_csv('scripts_updated.csv', index=False)
